# %%
import torch
import torch.nn as nn

# 定义卷积层
conv = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)

# 输入张量：batch_size=1, channels=3, height=32, width=32
input_tensor = torch.randn(1, 3, 32, 32)
# 前向传播
output = conv(input_tensor)
# print(output.shape)  # 输出：torch.Size([1, 16, 32, 32])


X = torch.rand(4, 3, 6, 6)

print(X)
# Out:
# tensor([[[[0.7810, 0.6072, 0.8384, 0.3030, 0.6358, 0.4702],
#           [0.9349, 0.9389, 0.3619, 0.8862, 0.8086, 0.4008],
#           [0.6408, 0.8476, 0.4314, 0.4334, 0.7158, 0.2944],
#           [0.3436, 0.6294, 0.3526, 0.7564, 0.6145, 0.9133],
#           [0.7987, 0.5653, 0.1269, 0.3491, 0.3584, 0.0692],
#           [0.6204, 0.3366, 0.5768, 0.2768, 0.9064, 0.0913]],
#
#          [[0.8055, 0.9349, 0.5503, 0.8214, 0.6212, 0.8085],
#           [0.5292, 0.9072, 0.2135, 0.0866, 0.7120, 0.1681],
#           [0.8688, 0.5836, 0.8170, 0.1342, 0.9981, 0.4918],
#           [0.1635, 0.5689, 0.0205, 0.2159, 0.0857, 0.9871],
#           [0.0499, 0.5826, 0.8440, 0.4207, 0.7575, 0.8711],
#           [0.2932, 0.3464, 0.3979, 0.0429, 0.2643, 0.0946]],
#
#          [[0.8657, 0.6396, 0.6875, 0.2771, 0.4227, 0.8589],
#           [0.3418, 0.0105, 0.5166, 0.1209, 0.1651, 0.0265],
#           [0.6543, 0.6152, 0.2456, 0.9510, 0.5945, 0.6329],
#           [0.9820, 0.7921, 0.8723, 0.5526, 0.0588, 0.0484],
#           [0.5399, 0.9880, 0.4191, 0.9727, 0.4033, 0.5910],
#           [0.0514, 0.3004, 0.2818, 0.4737, 0.8137, 0.0060]]],
#
#
#         [[[0.9706, 0.8549, 0.1402, 0.1588, 0.6421, 0.9596],
#           [0.8256, 0.7425, 0.0768, 0.3928, 0.8521, 0.4247],
#           [0.1096, 0.4991, 0.4998, 0.1718, 0.7528, 0.2152],
#           [0.1872, 0.8261, 0.9880, 0.0374, 0.2214, 0.3160],
#           [0.8592, 0.9947, 0.5189, 0.5460, 0.8632, 0.5264],
#           [0.5232, 0.0855, 0.5687, 0.9265, 0.7836, 0.7137]],
#
#          [[0.8389, 0.4784, 0.7557, 0.3137, 0.9090, 0.4391],
#           [0.5826, 0.1121, 0.3855, 0.9142, 0.6570, 0.2419],
#           [0.6710, 0.6657, 0.8483, 0.5695, 0.7626, 0.8630],
#           [0.7444, 0.9379, 0.2841, 0.2959, 0.5987, 0.7939],
#           [0.5293, 0.4149, 0.6085, 0.1841, 0.1827, 0.1177],
#           [0.2216, 0.0287, 0.5719, 0.3713, 0.2445, 0.2519]],
#
#          [[0.8295, 0.5481, 0.5885, 0.1074, 0.8880, 0.8287],
#           [0.8263, 0.3543, 0.0824, 0.9726, 0.0052, 0.9831],
#           [0.2701, 0.3157, 0.5279, 0.2712, 0.5225, 0.3214],
#           [0.5628, 0.4175, 0.2009, 0.6949, 0.7952, 0.0578],
#           [0.7301, 0.9954, 0.1531, 0.2816, 0.9079, 0.9736],
#           [0.5655, 0.1878, 0.8104, 0.0636, 0.9727, 0.0945]]],
#
#
#         [[[0.5717, 0.6079, 0.1173, 0.3464, 0.6320, 0.1187],
#           [0.8570, 0.1714, 0.3898, 0.6777, 0.6181, 0.9894],
#           [0.9356, 0.6882, 0.0715, 0.9895, 0.5434, 0.1744],
#           [0.5211, 0.1985, 0.7075, 0.3698, 0.0606, 0.3523],
#           [0.0601, 0.8308, 0.6821, 0.2397, 0.4545, 0.8675],
#           [0.9598, 0.6411, 0.0644, 0.9329, 0.4907, 0.4264]],
#
#          [[0.8737, 0.9096, 0.9162, 0.0671, 0.0730, 0.8769],
#           [0.8975, 0.2541, 0.1073, 0.2307, 0.7181, 0.7981],
#           [0.7590, 0.0393, 0.1967, 0.0775, 0.8194, 0.3646],
#           [0.3515, 0.5944, 0.3543, 0.3039, 0.8276, 0.8120],
#           [0.6565, 0.0143, 0.5899, 0.7792, 0.6116, 0.4828],
#           [0.3504, 0.7832, 0.5720, 0.3984, 0.5299, 0.2479]],
#
#          [[0.9288, 0.3869, 0.0458, 0.1030, 0.4238, 0.4226],
#           [0.7418, 0.3888, 0.7501, 0.6709, 0.3825, 0.0861],
#           [0.0066, 0.0549, 0.7659, 0.3318, 0.1070, 0.3905],
#           [0.6307, 0.9819, 0.8287, 0.8506, 0.6021, 0.6969],
#           [0.9090, 0.7911, 0.3699, 0.4476, 0.4538, 0.8260],
#           [0.8836, 0.6459, 0.5246, 0.1712, 0.3566, 0.8000]]],
#
#
#         [[[0.5910, 0.9155, 0.7201, 0.0511, 0.5731, 0.7426],
#           [0.8035, 0.1429, 0.6316, 0.6552, 0.5128, 0.6203],
#           [0.9357, 0.6052, 0.7382, 0.1548, 0.3427, 0.6771],
#           [0.8753, 0.3248, 0.8600, 0.3078, 0.6973, 0.8821],
#           [0.9179, 0.2786, 0.1423, 0.8983, 0.4246, 0.3275],
#           [0.4748, 0.7325, 0.9028, 0.0341, 0.9177, 0.4660]],
#
#          [[0.2742, 0.0668, 0.7702, 0.6272, 0.9655, 0.0917],
#           [0.2755, 0.2472, 0.4781, 0.2125, 0.1676, 0.5781],
#           [0.8648, 0.3813, 0.9457, 0.2205, 0.6951, 0.4416],
#           [0.0932, 0.9710, 0.3308, 0.0588, 0.7100, 0.9168],
#           [0.7785, 0.9111, 0.4593, 0.7668, 0.9247, 0.2392],
#           [0.1079, 0.9708, 0.9696, 0.7489, 0.8121, 0.5622]],
#
#          [[0.1190, 0.7687, 0.4991, 0.0685, 0.9458, 0.6005],
#           [0.1067, 0.0800, 0.5393, 0.2572, 0.4732, 0.3440],
#           [0.9468, 0.1381, 0.2580, 0.9494, 0.8546, 0.4282],
#           [0.6794, 0.5217, 0.6675, 0.9973, 0.6085, 0.0569],
#           [0.8050, 0.7006, 0.1443, 0.5469, 0.7231, 0.7111],
#           [0.9162, 0.1024, 0.1610, 0.7106, 0.2217, 0.6487]]]])
