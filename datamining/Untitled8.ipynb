# %%
coins = range(3,6)
for i in coins:
    print(i)


try:
    a = int(input("Enter first integer: "))
    b = int(input("Enter second integer: "))
    sum_ab = a + b
    diff_ab = a - b
    prod_ab = a * b
    quot_ab = a / b if b != 0 else "undefined (division by zero)"
    print(f"Sum: {sum_ab}, Difference: {diff_ab}, Product: {prod_ab}, Quotient: {quot_ab}")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter valid integers.")
# Out:
# 3
# 4
# 5
# Enter first integer: 323213
# Enter second integer: 3213213
# Sum: 3536426, Difference: -2890000, Product: 1038552213369, Quotient: 0.10058872536616775
