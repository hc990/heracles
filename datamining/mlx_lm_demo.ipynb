# %%
from mlx_lm import load,generate

model,tokenizer =load('mistralai/Mistral-7B-Instruct-v0.3')
# Out:
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# consolidated.safetensors:  48%|####7     | 13.4G/27.9G [00:00<?, ?B/s]
# ...

# %%
import mlx_lm
