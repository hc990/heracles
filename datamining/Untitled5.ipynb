# %%
# %time
import numpy as np
b = [1,2,3,4,5]
print(b[-2:-1])
c = [i for i in range(2,5)]
print(c)
i = 0
s = 0 
print(i > 100)
# while i <= 100:
#     s = s + i**2 
#     i = i + 1
#     print('=======')
#     print(i)
#     print(i**2)
#     print('=======')
# print(s)

s = "  hello"
print(s.rstrip('o'))  # 输出: hello
t = '432dsFFFfdwfdsf'
print(t.casefold())

print(len(s))

# a = np.random.rand(2,3,4,5)
# print(a)
# print(a.shape)
# print(np.mean(a,axis=(0,2,3),keepdims=True))
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# [4]
# [2, 3, 4]
# False
#   hell
# 432dsffffdwfdsf
# 7
