# %%
from mxnet import np
import random


w=np.array([2, -3.4])
noise=0.01
X = np.random.randn(4, len(w))
# print(X)
# print('=======')
y = np.dot(X, w.reshape((-1, 1)))  

# num_examples=10

# print(2*X[3][0]+X[3][1]*(-3.4))
# print('features:', X[3],'\nlabel:', y[3])
# print('X shape:', X.shape, '\ny shape:', y.shape)

# indices = list(range(0, 10))
# print(indices)
# random.shuffle(indices)# 打乱列表元素的顺序
# print(indices)

# X = np.random.normal(0, 1, (4, 7))# 生成0-1大小的 4* 7大小的矩阵
# print(X)

P = np.zeros(1)
print(P)

def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = np.array(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

# batch_size = 10
# b=0.01
# X = np.random.normal(0, 1, (num_examples, len(w)))# 生成0-1大小的 num_examples* len(w)的矩阵
# y = np.dot(X, w) + b
# print(y)
# print(y.shape)
# y += np.random.normal(0, 0.01, y.shape)
# # print(X)
# print(y)

def synthetic_data(w, b, num_examples):  #@save
    """生成y=Xw+b+噪声"""
    X = np.random.normal(0, 1, (num_examples, len(w)))
    print(X)
    y = np.dot(X, w) + b
    y += np.random.normal(0, 0.01, y.shape)
    print(X)
    return X, y.reshape((-1, 1))

true_w = np.array([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)
print(features)
print(labels)
# Out:
# [0.]
# [[-0.56771326  1.1397444 ]
#  [-0.6585852  -0.34262297]
#  [ 1.7185853  -1.9992297 ]
#  ...
#  [-0.58527803 -0.97377366]
#  [ 0.6239536   0.8873875 ]
#  [ 1.2356577   0.6373854 ]]
# [[-0.56771326  1.1397444 ]
#  [-0.6585852  -0.34262297]
#  [ 1.7185853  -1.9992297 ]
#  ...
#  [-0.58527803 -0.97377366]
#  [ 0.6239536   0.8873875 ]
#  [ 1.2356577   0.6373854 ]]
# [[-0.56771326  1.1397444 ]
#  [-0.6585852  -0.34262297]
#  [ 1.7185853  -1.9992297 ]
#  ...
#  [-0.58527803 -0.97377366]
#  [ 0.6239536   0.8873875 ]
#  [ 1.2356577   0.6373854 ]]
# [[-8.02148521e-01]
#  [ 4.05311632e+00]
#  [ 1.44347172e+01]
#  [ 8.85220337e+00]
#  [ 3.61971259e-01]
#  [ 1.09623375e+01]
#  [ 8.88732851e-01]
#  [ 4.24795389e+00]
#  [ 6.55082703e-01]
#  [ 7.93366194e+00]
#  [-1.05379558e+00]
#  [ 1.28443375e+01]
#  [ 2.85145760e+00]
#  [ 1.00226092e+00]
#  [ 2.15684399e-01]
#  [ 2.60988212e+00]
#  [ 2.32333565e+00]
#  [ 6.41737461e+00]
#  [ 8.94217670e-01]
#  [ 3.72870135e+00]
#  [ 2.60166311e+00]
# ...
