# %% [markdown]
# ### Which of the following is not a common cloud characteristic, as defined by NIST?
#
#     On-demand self-service
#     Measured service
#     Broad network access
#     Dedicated hardware”
#
# ### What is the term commonly used for the cloud’s capability to scale outward and inward automatically based on demand?”
#
#     Agility
#     Reliability
#     Elasticity
#     Fault tolerance
#
# ### What is the very popular “as a service” model that permits a cloud provider to make applications available anywhere there is an Internet connection?”
#
# “IaaS
# SaaS
# PaaS
# GaaS”
