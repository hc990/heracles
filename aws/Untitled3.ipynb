# %%
import openpyxl 

wb = openpyxl.load_workbook('/Users/huangchong/Downloads/11月18日盘点单.xlsx')
ws = wb.active

values = [ws.cell(row=1,column=i).value for i in range(1,ws.max_column+1)]
print(values)
# Out:
# ['序号', '原料名称', '原料编码', '原料规格', '盘点量 (期初)', '进货量 (上周)', '调拨 (数量和接收门店)', '盘点量 (期末)', '标准单位', '使用量', '订货量', '订货渠道', '备注', None, None, None, None, None, None, None, None, None, None, None, None, None]
