# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import PIL.Image
from IPython import display
from matplotlib_inline import backend_inline
import matplotlib.pyplot as plt

load_dotenv()
genai.configure(api_key=os.environ.get("GOOGLE_API_KEY"))

img = PIL.Image.open('/Users/huangchong/Downloads/23_HBD_Pokemon_1242_2688.jpg')

_, ax  = plt.subplots(1,1,figsize=(10,2))
ax.imshow(img)

model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content(img)

print(response.text)
# Out:
#  The image is a celebration of the release of the new Pokémon games, Scarlet and Violet. The image features several Pokémon, including Pikachu, Sprigatito, Fuecoco, Quaxly, Lechonk, and Pawmi. The Pokémon are all depicted as happy and excited, and they are surrounded by colorful balloons and confetti. The background is a light blue color, and the overall tone of the image is one of happiness and celebration.
