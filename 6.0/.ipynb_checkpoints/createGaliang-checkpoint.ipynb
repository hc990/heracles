# %%
from smb.SMBConnection import SMBConnection
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime
import os
import fitz
import ebooklib
from ebooklib import epub
from PIL import Image
import io
from imghdr import what

def extract_cover(epub_path, cover_path, thumbnail_size=(100, 150)):
    try:
        book = epub.read_epub(epub_path)
#         for item in book.get_items():
#             print(item)
        cover_id = None
        for item in book.get_metadata('OPF', 'meta'):
            if item.get('name') == 'cover':
                cover_id = item.get('content')
                break
        if cover_id:
            cover_image = book.get_item_with_id(cover_id)
        else:
            cover_image = None
   
        if not cover_image:           
            for item in book.get_items():
                if  item.media_type.startswith('image/') :
                    if 'cover' in item.get_name().lower():
                        cover_image = item
                        break    
                    
        if not cover_image:
            for item in book.get_items_of_type(epub.ITEM_IMAGE):
                if 'cover' in item.get_name().lower():
                    cover_image = item
                    break 
                
        cover_content = cover_image.get_content()
        image = Image.open(io.BytesIO(cover_content))
        thumbnail = image.resize(thumbnail_size)
        thumbnail.save(cover_path)
    except:
        print(epub_path+'未生成縮略圖')
        
def generate_thumbnail(pdf_path, thumbnail_path):
    try:
        pdf_document = fitz.open(pdf_path)  # 打开 PDF 文件
        if pdf_document.page_count == 0:
            raise ValueError("PDF 文件没有页面")
        first_page = pdf_document[0]
        rect = first_page.rect  # 页面尺寸
        pixmap = first_page.get_pixmap(matrix=fitz.Matrix(0.5, 0.5))  # 创建缩略图
        pixmap.save(thumbnail_path)  # 保存缩略图
    except Exception as e:
        print(f"生成缩略图失败: {e}")
    pdf_document.close()# Close the PDF document
    

server_name = 'mongodb+srv://huangchong:NVHYEx8HSzYHS6ra@ceair-cluster.wootsqu.mongodb.net'
client = MongoClient(server_name,server_api=ServerApi('1'))
db = client.test

# conn = SMBConnection(userID, password, client_machine_name, server_name, domain=domain_name, use_ntlm_v2=True,
#                      is_direct_tcp=True)
# conn.connect(server_ip, 445)
# shares = conn.listShares()
# db.books.drop()

PATH=r'/Users/huangchong/SynologyDrive/books'
# PATH=r'/volume2/library/books'
# /volume2/library/books

i=1;
for filename in os.listdir(PATH):
#     if not share.isSpecial and share.name == 'library':
#         sharedfiles = conn.listPath(share.name, '/books')
#       print(dirname)
#       for filename in filenames:
        if 'pdf' in filename or 'epub' in filename: 
            name,extend = filename.rsplit(".", 1) 
            oribookname = filename
            bookname = filename
            bookname = bookname.translate({ord('['): None})
            bookname = bookname.translate({ord(']'): None})
            bookname = bookname.replace('.扫描版','')
            bookname = bookname.replace(' (Z-Library)','')
            bookname = bookname.replace('&amp;','.')
            if '.' in bookname:
                name,extend = bookname.rsplit(".", 1) 
                file_stat = os.stat(os.path.join(PATH, filename))
                book = db.books.insert_one({'oribookname': oribookname,'bookname': bookname,\
                                     'name': name.lower(),'extend': extend.lower(),'serial': i, \
                                 'createAt': datetime.fromtimestamp(file_stat.st_ctime)  ,\
                                    'comment':"", 'status':0,'size': file_stat.st_size/1024/1024})
               
            i=i+1;
            file_path = os.path.join(PATH, filename)
            
            thumbnail_path = PATH+'/thumbnail/'+str(book.inserted_id)+'.png'
            print(thumbnail_path)
            if('pdf' in filename):
                try:
                    generate_thumbnail(file_path, thumbnail_path)
                except Exception as e:
                    print(f"处理文件 {file_path} 时出错: {e}")
            if('epub' in filename):
                extract_cover(file_path, thumbnail_path)
            print(bookname)
# conn.close()
# Out:
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c659fcd101dce08e2a20.png
# エイトマン15周年企画　8woman　rouge　美乃すずめ×鷲尾めい (美乃すずめ, 鷲尾めい).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c65cfcd101dce08e2a21.png
# /Users/huangchong/Virtualenvs/heracles/lib/python3.10/site-packages/ebooklib/epub.py:1395: UserWarning: In the future version we will turn default option ignore_ncx to True.
#   warnings.warn('In the future version we will turn default option ignore_ncx to True.')
# The Food of Northern Thailand (Austin Bush).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c65dfcd101dce08e2a22.png
# 4号黄思棋.pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c65dfcd101dce08e2a23.png
# 吳哥深度導覽：神廟建築、神話傳說、藝術解析完整版 (張蘊之).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c65ffcd101dce08e2a24.png
# 縱走日本二千哩 (亞蘭 布斯).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c65ffcd101dce08e2a25.png
# 神話：眾神的造物、戲弄和懲罰 (［英］斯蒂芬·弗萊（Stephen Fry）黃天怡譯).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c660fcd101dce08e2a26.png
# 中国考古学界对先秦天⽂历法⼀窍不通很无知 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c660fcd101dce08e2a27.png
# 革命年代 (高华).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c660fcd101dce08e2a28.png
# 大腦喜歡這樣學：先認識自己的大腦，找到正確的思考路徑，就能專注、不拖延，提高記憶力，學會如何學習 (二版) A Mind for Numbers (Barbara Oakley 芭芭....epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c662fcd101dce08e2a29.png
# 边缘, 族群与国家清末西北回民起义 (周耀明).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c662fcd101dce08e2a2a.png
# The Nyonya Kebaya  A Century of Straits Chinese Costume (Datin Seri).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c663fcd101dce08e2a2b.png
# 神好多的日本（神明谱系扫盲：从汉字出发，解读日本“八百万”神明诞生的秘密！探寻黑泽明、新海诚等人作品中神社元素的意义） (未读·文艺家)....epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c663fcd101dce08e2a2c.png
# Growing carnivorous plants (Barry Rice).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c663fcd101dce08e2a2d.png
# 日本神話故事 (洪維揚).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c664fcd101dce08e2a2e.png
# 在历史的风陵渡口 (高华).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c664fcd101dce08e2a2f.png
# 陶哲轩教你学数学 (陶哲轩(Terence Tao)).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c664fcd101dce08e2a30.png
# Carnivorous Plants Physiology, ecology, and evolution (Aaron Ellison, Lubomír Adamec).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c665fcd101dce08e2a31.png
# 规矩方圆 ，天地之和（中国古代都城、建筑群与单体建筑之构图比例研究）上册 (王南).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c665fcd101dce08e2a32.png
# 横扫一切关于三星堆的谎言【随笔辑录】 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c666fcd101dce08e2a33.png
# 圖解克蘇魯神話 (森瀨繚).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c667fcd101dce08e2a34.png
# 海怪：中世纪与文艺复兴时期地图中的海洋异兽 (切特·凡·杜泽).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c667fcd101dce08e2a35.png
# /Users/huangchong/SynologyDrive/books/500种野菜野外识别速查图鉴 (岳桂华（化学工业出版社）) (Z-Library).epub未生成縮略圖
# 500种野菜野外识别速查图鉴 (岳桂华（化学工业出版社）).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c667fcd101dce08e2a36.png
# 英雄 (［英］斯蒂芬·弗莱（Stephen Fry）黄天怡译 Fry）黄天怡译 etc.).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c668fcd101dce08e2a37.png
# /Users/huangchong/SynologyDrive/books/為什麼一流人才的專注力能持續一整天？：日本外科權威南雲醫師教你強化專注力的60個習慣 (南雲吉則(Yoshinori Nagumo)) (Z-Library).epub未生成縮略圖
# 為什麼一流人才的專注力能持續一整天？：日本外科權威南雲醫師教你強化專注力的60個習慣 (南雲吉則(Yoshinori Nagumo)).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c668fcd101dce08e2a38.png
# 近藏集粹 中国国家博物馆新入藏文物【无版权页，目录有重复】 (吕章申 主编).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c668fcd101dce08e2a39.png
# 南京民國建築地圖 (劉屹立).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c669fcd101dce08e2a3a.png
# 中国妖怪故事 (张云).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c669fcd101dce08e2a3b.png
# 順著大腦習性，懶人也有高績效：靠意志力只會中途放棄，腦神經醫師教你指揮大腦不拖拉，恆毅力、專注力大幅提升！= 「めんどくさい」がなくな....epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c669fcd101dce08e2a3c.png
# 8woman　エイトマン女優8人のいちばん長い日 アサ芸SEXY女優写真集 (葵つかさ, 吉高寧々, 美乃すずめ, 鷲尾めい, 七海ティナ, 桃尻かなめ, 天国るる etc.).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66afcd101dce08e2a3d.png
# 诺玛阿美到哀牢山 (黄绍文著, Huang Shaowen zhu etc.).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66afcd101dce08e2a3e.png
# Phalaenopsis - A Complete Guide (David Lafarge).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66bfcd101dce08e2a3f.png
# /Users/huangchong/SynologyDrive/books/亡灵书 (雷蒙德·福克纳) (Z-Library).epub未生成縮略圖
# 亡灵书 (雷蒙德·福克纳).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66bfcd101dce08e2a40.png
# 天文考古学【专题篇】：由《尧典》“四仲中星”实测年代完美论证颛顼帝喾尧舜禹王年断代 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66cfcd101dce08e2a41.png
# 万物：中国艺术中的模件和规模化生产 (德雷德侯著  张总  钟晓青  陈芳  韦正  赵州译).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66cfcd101dce08e2a42.png
# 生成缩略图失败: PDF 文件没有页面
# 诺玛阿美到哀牢山 (黄绍文著, Huang Shaowen zhu etc.).pdf.crdownload
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66cfcd101dce08e2a43.png
# 哀牢传奇 (熊长麟，彭耀华著).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66dfcd101dce08e2a44.png
# Cultivating Carnivorous Plants (Natch Greyes).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c66ffcd101dce08e2a45.png
# 哀牢山的画卷 (王正芳著).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c670fcd101dce08e2a46.png
# /Users/huangchong/SynologyDrive/books/讲谈社·中国的历史01·从神话到历史：神话时代夏王朝 (宫本一夫) (Z-Library).epub未生成縮略圖
# 讲谈社·中国的历史01·从神话到历史：神话时代夏王朝 (宫本一夫).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c670fcd101dce08e2a47.png
# 沉香鉴定与选购从新手到行家_刘岩_文化发展 (沉香鉴定与选购从新手到行家_刘岩_文化发展).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c670fcd101dce08e2a48.png
# 生成缩略图失败: PDF 文件没有页面
# 哀牢山的画卷 (王正芳著).pdf.crdownload
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c671fcd101dce08e2a49.png
# Orchids of Britain and Ireland A Field and Site Guide, Second Edition (Anne Harrap, Simon Harrap).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c671fcd101dce08e2a4a.png
# 威尼斯共和國：稱霸地中海的海上商業帝國千年史 (湯瑪士．麥登(Thomas F. Madden)).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c671fcd101dce08e2a4b.png
# 天文考古学【基础篇】：用黄经和二十八宿等坐标标记二十四节气 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c672fcd101dce08e2a4c.png
# 规矩方圆 ，天地之和（中国古代都城、建筑群与单体建筑之构图比例研究）下册 (王南).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c672fcd101dce08e2a4d.png
# 宋本历代地理指掌图 (北宋税安礼).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c672fcd101dce08e2a4e.png
# Hunan A Lifetime of Secrets from Mr Pengs Chinese Kitchen (Mr Peng).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c674fcd101dce08e2a4f.png
# 三星堆、古埃及、天文历法：中国百年考古和上古历史研究的崩盘和涅槃【上】 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c674fcd101dce08e2a50.png
# Orchid A Cultural History (Jim Endersby).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c675fcd101dce08e2a51.png
# Jang  The Soul of Korean Cooking — More than 60 Recipes Featuring Gochujang, Doenjang, and Ganjang (Mingoo Kang).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c675fcd101dce08e2a52.png
# 九色鹿萨满教 古老的入迷术 (米尔恰·伊利亚德).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c675fcd101dce08e2a53.png
# Authentic Recipes from Singapore 63 Simple and Delicious Recipes from the Tropical Island City-State (Djoko Wibisono, David Wong etc.).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c676fcd101dce08e2a54.png
# 關氏所藏中國古玉 (楊伯逹).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c676fcd101dce08e2a55.png
# 民国江湖：民国帮会秘闻 (王梅英).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c676fcd101dce08e2a56.png
# Amazing Malaysian Recipes for Vibrant Malaysian Home Cooking (Norman Musa).epub
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c677fcd101dce08e2a57.png
# 天文考古学【进阶篇】：由次度表再证颛顼元年及古埃及即华夏 (道非常).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c677fcd101dce08e2a58.png
# 巫鬼與淫祀：楚簡所見方術宗教考 (晏昌貴).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c678fcd101dce08e2a59.png
# 元阳新街 哀牢山情梯田水意 (钟相达著, 彭晓主编 , 易晖编著, 彭晓, 易晖, 高春林, 詹霖).pdf
# /Users/huangchong/SynologyDrive/books/thumbnail/6743c679fcd101dce08e2a5a.png
# 法老的诅咒 探寻古埃及神秘的巫术与宗教 (郭丹彤，马晓敏著).pdf
