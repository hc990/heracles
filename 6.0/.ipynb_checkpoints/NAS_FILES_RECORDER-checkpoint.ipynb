# %%
from smb.SMBConnection import SMBConnection
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import datetime



userID = 'reader'
password = 'Huang990_'
client_machine_name = '192.168.2.250'

server_name = 'PaloAlto'
server_ip = '192.168.2.214'
domain_name = 'PaloAlto'

# client = MongoClient(server_ip, 27277)

server_name = 'mongodb+srv://huangchong:4qjuebnbxGsSQD29@ceair-cluster.wootsqu.mongodb.net'
client = MongoClient(server_name,server_api=ServerApi('1'))

db = client.test

conn = SMBConnection(userID, password, client_machine_name, server_name, domain=domain_name, use_ntlm_v2=True,
                     is_direct_tcp=True)
conn.connect(server_ip, 445)
# shares = conn.listShares()
# db.books.drop()
i=1;
for share in shares:
    if not share.isSpecial and share.name == 'library':
        sharedfiles = conn.listPath(share.name, '/books')
        for sharedfile in sharedfiles:
            print(sharedfile.filename)
            oribookname = sharedfile.filename
            bookname = sharedfile.filename
            bookname = bookname.translate({ord('['): None})
            bookname = bookname.translate({ord(']'): None})
            bookname = bookname.replace('.扫描版','')
            bookname = bookname.replace(' (Z-Library)','')
            bookname = bookname.replace('&amp;','.')
            if '.' in bookname:
                name,extend = bookname.rsplit(".", 1) 
                db.books.insert_one({'serial':i,'oribookname':oribookname,'bookname':bookname,'name':name.lower(), 'extend':extend.lower(), \
                                 'createAt': datetime.datetime.fromtimestamp(sharedfile.create_time),\
                                     'status':0,'size':sharedfile.alloc_size/1024/1024})
            i=i+1;
conn.close()
# Out:
# .
# ..
# (成年コミック) [織田non] NON VIRGIN [DL版]
# .DS_Store
# 01.[论语].张燕婴.译注.扫描版.pdf
# 02.[孟子].万丽华.蓝旭译注.扫描版.pdf
# 03.[大学.中庸].王国轩.译注.扫描版.pdf
# 034-韩国顶级模特儿LEE大尺度超长现场  大奶瓜子，各种透明内衣 若隐若现，9分超高颜值的超女神
# 04.[诗经].王秀梅.译注.扫描版.pdf
# 05.[尚书].慕平.译注.扫描版.pdf
# 06.[礼记.孝经].胡平生.陈美兰.译注.扫描版.pdf
# 07.[周易].郭彧.译注.扫描版.pdf
# 08.[老子].饶尚宽.译注.扫描版.pdf
# 09.[墨子].李小龙.译注.扫描版.pdf
# 10.[晏子春秋].陈涛.译注.扫描版.pdf
# 1000 Nudes Uwe Scheid collection  [engl.ish-deutsch-francais] (Michael Koetzle) (Z-Library).pdf
# 1000 Useful Words - Build Vocabulary and Litera... (Z-Library).pdf
# 101 Great Samurai Prints (Utagawa Kuniyoshi, John Grafton) (Z-Library).epub
# 10～13世纪古格王国政治史研究【揭开中国西藏历史上古国王国的神秘面纱】 (九色鹿) (黄博 [黄博]) (Z-Library).epub
# 10～13世纪古格王国政治史研究【揭开中国西藏历史上古国王国的神秘面纱】 (九色鹿) (黄博) (Z-Library).mobi
# 11.[曾子.子思子].陈桐生.译注.扫描版.pdf
# 12.[孔丛子].王钧林.周海生.译注.扫描版.pdf
# 13.[庄子].孙通海.译注.扫描版.pdf
# 14.[管子].李山.译注.扫描版.pdf
# 15.[荀子].安小兰.译注.扫描版.pdf
# ...
