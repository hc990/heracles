# %%
from smb.SMBConnection import SMBConnection
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import datetime
import os
from pathlib import Path
import fitz  # PyMuPDF
import ebooklib
from ebooklib import epub
from PIL import Image
import io
import os
from dotenv import load_dotenv



def generate_thumbnail(pdf_path, thumbnail_path):
    pdf_document = fitz.open(pdf_path)# Open the PDF file
    first_page = pdf_document[0]# Get the first page    
    rect = first_page.rect# Get the dimensions of the first page
    pixmap = first_page.get_pixmap(matrix=fitz.Matrix(0.5, 0.5))# Create a pixmap for the first page
    pixmap.save(thumbnail_path)# Save the pixmap as an image file (e.g., PNG)
    pdf_document.close()# Close the PDF document
    
def extract_cover(epub_path, cover_path, thumbnail_size=(100, 150)):
    # Open the EPUB file
    try:
        book = epub.read_epub(epub_path)
#         for item in book.get_items():
#             print(item)
        cover_id = None
        for item in book.get_metadata('OPF', 'meta'):
            if item.get('name') == 'cover':
                cover_id = item.get('content')
                break
        if cover_id:
            cover_image = book.get_item_with_id(cover_id)
        else:
            cover_image = None
   
        if not cover_image:           
            for item in book.get_items():
                if  item.media_type.startswith('image/') :
                    if 'cover' in item.get_name().lower():
                        cover_image = item
                        break    
                    
        if not cover_image:
            for item in book.get_items_of_type(epub.ITEM_IMAGE):
                if 'cover' in item.get_name().lower():
                    cover_image = item
                    break 
                
        cover_content = cover_image.get_content()
        image = Image.open(io.BytesIO(cover_content))
        thumbnail = image.resize(thumbnail_size)
        thumbnail.save(cover_path)
    except:
        print(epub_path+'未生成縮略圖')
        
load_dotenv()
              
userID = os.environ.get("NAS_USERNAME")
password = os.environ.get("NAS_PASSWORD")
client_machine_name = '192.168.2.250'

print(userID)
print(password)

server_name = 'PaloAlto'
server_ip = '192.168.2.214'
domain_name = 'PaloAlto'

conn = SMBConnection(userID, password, client_machine_name, server_name, domain=domain_name, use_ntlm_v2=True,
                     is_direct_tcp=True)
conn.connect(server_ip, 445)

server_name = 'mongodb+sr://huangchong:NVHYEx8HSzYHS6ra@ceair-cluster.wootsqu.mongodb.net'
client = MongoClient(server_name,server_api=ServerApi('1'))

db = client.test

folder_path = Path('/Users/huangchong/SynologyDrive/books')
thumbnail_path = Path('/Users/huangchong/SynologyDrive/thumbnail')

# 递归遍历文件夹中的所有文件和子文件夹
for item in folder_path.iterdir():
    if item.is_file():
        file_path = os.path.join(folder_path, item.name)
        print(f'File: {file_path}')
        oribookname = item.name
        bookname = item.name  
        bookname = bookname.translate({ord('['): None})
        bookname = bookname.translate({ord(']'): None})
        bookname = bookname.replace('.扫描版','')
        bookname = bookname.replace(' (Z-Library)','')
        bookname = bookname.replace('&amp;','.')
        if '.' in bookname:
            name,extend = bookname.rsplit(".", 1) 
#             book = db.books_demo.insert_one({'oribookname':oribookname,'bookname':bookname,'name':name.lower(), 'extend':extend.lower(), \
#                                  'createAt': datetime.datetime.fromtimestamp(item.stat().st_mtime),\
#                                      'status':0,'size':round(item.stat().st_size/1024/1024,2)})
#             print(item.suffix)
#             if 'pdf' in item.suffix: 
#                 generate_thumbnail(file_path,os.path.join(thumbnail_path, str(book.inserted_id) +'.png'))
#             if 'epub' in item.suffix: 
#                 extract_cover(file_path,os.path.join(thumbnail_path, str(book.inserted_id) +'.png'))
# Out:
# None
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 75
#      71 domain_name = 'PaloAlto'
#      73 conn = SMBConnection(userID, password, client_machine_name, server_name, domain=domain_name, use_ntlm_v2=True,
#      74                      is_direct_tcp=True)
# ---> 75 conn.connect(server_ip, 445)
#      77 server_name = 'mongodb+srv://huangchong:4qjuebnbxGsSQD29@ceair-cluster.wootsqu.mongodb.net'
#      78 client = MongoClient(server_name,server_api=ServerApi('1'))
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/SMBConnection.py:129, in SMBConnection.connect(self, ip, port, sock_family, timeout)
#     127         self.onNMBSessionOK()
#     128     while self.auth_result is None:
# --> 129         self._pollForNetBIOSPacket(timeout)
#     130 finally:
#     131     self.is_busy = False
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/SMBConnection.py:649, in SMBConnection._pollForNetBIOSPacket(self, timeout)
#     646         else:
#     647             raise ex
# --> 649 self.feedData(data)
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/nmb/base.py:54, in NMBSession.feedData(self, data)
#      52 elif length > 0:
#      53     offset += length
# ---> 54     self._processNMBSessionPacket(self.data_nmb)
#      55 else:
#      56     raise NMBError
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/nmb/base.py:75, in NMBSession._processNMBSessionPacket(self, packet)
#      73 def _processNMBSessionPacket(self, packet):
#      74     if packet.type == SESSION_MESSAGE:
# ---> 75         self.onNMBSessionMessage(packet.flags, packet.data)
#      76     elif packet.type == POSITIVE_SESSION_RESPONSE:
#      77         self.onNMBSessionOK()
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/base.py:150, in SMB.onNMBSessionMessage(self, flags, data)
#     146     else:
#     147         self.log.debug('Received SMB2 message "%s" (command:0x%04X flags:0x%04x)',
#     148                        SMB2_COMMAND_NAMES.get(self.smb_message.command, '<unknown>'),
#     149                        self.smb_message.command, self.smb_message.flags)
# --> 150     if self._updateState(self.smb_message):
#     151         # We need to create a new instance instead of calling reset() because the instance could be captured in the message history.
#     152         self.smb_message = self._klassSMBMessage()
#     154 if next_message_offset > 0:
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/base.py:291, in SMB._updateState_SMB2(self, message)
#     289     result, ntlm_token = securityblob.decodeChallengeSecurityBlob(message.payload.security_blob)
#     290     if result == securityblob.RESULT_ACCEPT_INCOMPLETE:
# --> 291         self._handleSessionChallenge(message, ntlm_token)
#     292 except ( securityblob.BadSecurityBlobError, securityblob.UnsupportedSecurityProvider ) as ex:
#     293     raise ProtocolError(str(ex), message.raw_data, message)
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/base.py:370, in SMB._handleSessionChallenge_SMB2(self, message, ntlm_token)
#     368 if self.use_ntlm_v2:
#     369     self.log.info('Performing NTLMv2 authentication (on SMB2) with server challenge "%s"', binascii.hexlify(server_challenge))
# --> 370     nt_challenge_response, lm_challenge_response, session_key = ntlm.generateChallengeResponseV2(self.password,
#     371                                                                                                  self.username,
#     372                                                                                                  server_challenge,
#     373                                                                                                  server_info,
#     374                                                                                                  self.domain)
#     376 else:
#     377     self.log.info('Performing NTLMv1 authentication (on SMB2) with server challenge "%s"', binascii.hexlify(server_challenge))
#
# File ~/Virtualenvs/heracles/lib/python3.10/site-packages/smb/ntlm.py:170, in generateChallengeResponseV2(password, user, server_challenge, server_info, domain, client_challenge)
#     167 assert len(client_challenge) == 8
#     169 d = MD4()
# --> 170 d.update(password.encode('UTF-16LE'))
#     171 ntlm_hash = d.digest()   # The NT password hash
#     172 response_key = hmac.new(ntlm_hash, (user.upper() + domain).encode('UTF-16LE'), 'md5').digest()  # The NTLMv2 password hash. In [MS-NLMP], this is the result of NTOWFv2 and LMOWFv2 functions
#
# AttributeError: 'NoneType' object has no attribute 'encode'
