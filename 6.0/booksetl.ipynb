# %%
from pymongo import MongoClient

from pymongo.server_api import ServerApi

server_name = 'mongodb+srv://huangchong:4qjuebnbxGsSQD29@ceair-cluster.wootsqu.mongodb.net'
client = MongoClient(server_name,server_api=ServerApi('1'))

db = client.test

books =  db.books.find();
for book in books:
    if 'name' in book:
        bookname = book['name']
        if '.' in bookname:
            bookname =bookname.translate({ord('['): None})
            bookname = bookname.translate({ord(']'): None})
            bookname = bookname.replace('.扫描版','')
            bookname = bookname.replace(' (Z-Library)','')
            bookname = bookname.replace('&amp;','.')
            name,extend = bookname.rsplit(".", 1) 
            print(bookname)
            print(name)
            print(extend)
            db.books.update_one({'_id':book['_id']},{'$set':{'bookname':name,'extend':extend}});
            i = 1
            while '.' in name:
                name,extend = name.rsplit(".", 1) 
                print(name)
                print(extend)
                db.books.update_one({'_id':book['_id']},{'$set':{'booknamebak_'+str(i):name, 'extend_'+str(i):extend}});
                i=i+1;
# Out:
# .
#
#
# 10堂量子创意课.李欣频著
# 10堂量子创意课
# 李欣频著
# “天国之子”和他的世俗王朝：洪秀全与太平天国.美史景迁
# “天国之子”和他的世俗王朝：洪秀全与太平天国
# 美史景迁
# 不去会死.（日）石田裕辅著
# 不去会死
# （日）石田裕辅著
# 世界是数字的.brian.w.kernighan
# 世界是数字的.brian.w
# kernighan
# 世界是数字的.brian
# w
# 世界是数字的
# brian
# 中国历代蟋蟀谱集成.上卷.王世襄.上海文化出版社.2012-10-1(简体)
# 中国历代蟋蟀谱集成.上卷.王世襄.上海文化出版社
# 2012-10-1(简体)
# 中国历代蟋蟀谱集成.上卷.王世襄
# 上海文化出版社
# 中国历代蟋蟀谱集成.上卷
# 王世襄
# 中国历代蟋蟀谱集成
# 上卷
# 中国历代蟋蟀谱集成.下卷.王世襄.上海文化出版社.2012-10-1(简体)
# 中国历代蟋蟀谱集成.下卷.王世襄.上海文化出版社
# 2012-10-1(简体)
# 中国历代蟋蟀谱集成.下卷.王世襄
# 上海文化出版社
# 中国历代蟋蟀谱集成.下卷
# 王世襄
# 中国历代蟋蟀谱集成
# 下卷
# 中国手绘.第2辑.夏克梁
# 中国手绘.第2辑
# 夏克梁
# 中国手绘
# 第2辑
# 中国皇帝：康熙自画像.(美)史景迁
# 中国皇帝：康熙自画像
# (美)史景迁
# 云南摄影之旅.彩印.上海唐码城邦咨询有限公司北京.彩图版
# 云南摄影之旅.彩印.上海唐码城邦咨询有限公司北京
# 彩图版
# 云南摄影之旅.彩印
# 上海唐码城邦咨询有限公司北京
# 云南摄影之旅
# 彩印
# 云端时代杀手级应用：大数据分析.胡世忠
# 云端时代杀手级应用：大数据分析
# 胡世忠
# 云雨.江晓原
# 云雨
# 江晓原
# 人间是剧场.（不丹）宗萨蒋扬钦哲仁波切
# 人间是剧场
# （不丹）宗萨蒋扬钦哲仁波切
# 叔本华：怎样读书才有效.（德）叔本华
# 叔本华：怎样读书才有效
# （德）叔本华
# 古代汉语(校订重排本).全4册.王力
# 古代汉语(校订重排本).全4册
# 王力
# 古代汉语(校订重排本)
# 全4册
# 名画家刻紫砂壶丛书.何建国卷.何建国.江西美术出版社.2011-7-1(简体)
# ...
